# %%
# from dotenv import load_dotenv
# from os import getenv

# %%
# from langchain_openai import ChatOpenAI
# from langchain.prompts import PromptTemplate
# from langchain.tools import tool
# from langgraph.prebuilt import create_react_agent

# # Define the model
# llm_model = ChatOpenAI(model="gpt-4o-mini")

# # Define the system prompt
# system_prompt = (
#     "You are an AI agent that assists content creators in creating videos for different brands based on the brand type like clothing, footware, glasses, etc.\n"
#     "If you find the keywords like clothing, footware or glasses, suggest scripts on the basis of that"
#     "Give answers in a stepwise format and print each step on a different line."
# )

# # Define tools using @tool decorator with docstrings
# @tool
# def create_script(topic: str) -> str:
#     """
#     Create a script for a video based on the given topic.
#     """
#     return f"This is a script about {topic}"

# @tool
# def create_video(script: str) -> str:
#     """
#     Create a video using the provided script.
#     """
#     return f"Video created using script: {script}"

# @tool
# def create_voice_over(script: str) -> str:
#     """
#     Create a voice-over based on the provided script.
#     """
#     return f"Voice-over created for script: {script}"

# # List of tools
# tools = [create_script, create_video, create_voice_over]

# # Create the agent
# agent = create_react_agent(
#     prompt=system_prompt,
#     model=llm_model,
#     tools=tools
# )

# %%
# from langchain_core.messages.ai import AIMessage
# from langchain_core.messages import HumanMessage

# query = (
#     "I have a brand with brand type **footwear**, brand name **aesha**, "
#     "and I want to launch new products for summer. Suggest me video content ideas for that."
# )

# state = {
#     "messages": [HumanMessage(content=query)]
# }

# #Invoke the agent
# response = agent.invoke(state)

# messages = response.get("messages", [])
# ai_messages = [m.content for m in messages if isinstance(m, AIMessage)]

# if ai_messages:
#     print(ai_messages[-1])
# else:
#     print("No AI message in response.")
# Out:
# Here are some video content ideas for your footwear brand **Aesha** launching new summer products:
#
# 1. **Summer Collection Reveal**
#    - Showcase the new summer footwear collection with vibrant visuals, emphasizing colors and styles perfect for the season.
#
# 2. **Styling Tips for Summer**
#    - Create a video featuring styling tips on how to pair the new footwear with summer outfits, including dresses, shorts, and swimwear.
#
# 3. **Behind-the-Scenes**
#    - Give viewers a behind-the-scenes look at the design and production process of the new summer footwear.
#
# 4. **Customer Testimonials**
#    - Feature satisfied customers trying on the new summer shoes and sharing their experiences and favorite styles.
#
# 5. **Summer Footwear Care Tips**
#    - Provide viewers with tips on how to care for and maintain their summer footwear to keep them looking great all season long.
#
# 6. **Outdoor Adventure Lookbook**
#    - Create a lookbook video that showcases different outdoor activities while wearing Aesha's summer footwear, like beach outings, picnics, or hikes.
#
# 7. **Social Media Challenge**
#    - Encourage viewers to participate in a challenge wearing their new summer sandals and sharing their adventures on social media.
#
# 8. **Footwear Fashion Show**
#    - Organize a mini fashion show highlighting the new summer collection, featuring influencers or models wearing the styles in different settings.
#
# 9. **Summer Travel Essentials**
#    - Create a video discussing the must-have Aesha footwear for summer travel, highlighting their versatility and comfort.
#
# 10. **Interactive Q&A Session**
#     - Host a live Q&A session where potential customers can ask questions about the new summer footwear and receive styling advice.
#
# These ideas can help engage your audience and promote the new summer collection effectively!

# %%
# from langgraph.graph import StateGraph, START, END
# from Rag_agents.basemodel import OverallState  
# from Rag_agents.models.llm_models import LLMReasoningNode
# from Rag_agents.services.serpai import SerpAPINode
# from Rag_agents.services.script import ScriptNode
# from Rag_agents.services.video import VideoNode

# import nest_asyncio
# nest_asyncio.apply()

# from IPython.display import Image, display
# from langchain_core.runnables.graph import MermaidDrawMethod



# # def build_graph():
# builder = StateGraph(OverallState)

# # Add the nodes (they must implement .run(state) -> state)
# builder.add_node("LLM Reasoning", LLMReasoningNode().run)
# builder.add_node("Hashtag_gen", SerpAPINode().run)
# builder.add_node("Script Generation", ScriptNode().run)
# builder.add_node("Video Generation", VideoNode().run)

# builder.add_edge(START, "LLM Reasoning")

# # Define routing logic
# def route_selector(state: OverallState) -> str:
#     # You can use `state.get("some_key")` if unsure the key exists
#     if state.get("video"):
#         return "complete"

#     next_route = state.get("next_route")
#     if next_route in ["Hashtag_gen", "Script Generation", "Video Generation"]:
#         return next_route

#     return "complete"

# builder.add_conditional_edges(
#     "LLM Reasoning",
#     route_selector,
#     {
#         "Hashtag_gen": "Hashtag_gen",
#         "Script Generation": "Script Generation",
#         "Video Generation": "Video Generation",
#         "complete": END,
#     },
# )

# # Loop edges back to LLM
# builder.add_edge("Hashtag_gen", "LLM Reasoning")
# builder.add_edge("Script Generation", "LLM Reasoning")
# builder.add_edge("Video Generation", "LLM Reasoning")
# # return workflow


# # Code to draw graph

# %%
# workflow = builder.compile()

# display(Image(workflow.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)))

# %%
#
